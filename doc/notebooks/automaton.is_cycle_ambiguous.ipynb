# %% [markdown]
# # _automaton_.is_cycle_ambiguous
#
# Whether the automaton is _cycle ambiguous_, i.e., there exist a state $s$ and a label $x$ such that there is more than one cycle in $s$ labeled with $x$.
#
# Preconditions:
# - the automaton is free.

# %% [markdown]
# ## Examples

# %%
import vcsn

# %%
# %%automaton -s a
# context = "lal_char, b"
# $ -> 0
# 0 -> $
# 0 -> 1 a
# 0 -> 2 a
# 1 -> 0 b
# 2 -> 0 b
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %% [markdown]
# At state $0$, the automaton has two cycles "ab" so it is cycle ambiguous.

# %%
a.is_cycle_ambiguous()
# Out:
# True

# %%
# %%automaton -s a
# context = "lal_char, b"
# $ -> 0
# 0 -> $
# 0 -> 1 a
# 0 -> 2 a
# 1 -> 0 b
# 2 -> 0 c
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %% [markdown]
# At state $0$, the automaton has two cycles with different label "ab", "ac" so it is not cycle ambiguous (it is _cycle-unambiguous_).

# %%
a.is_cycle_ambiguous()
# Out:
# False

# %%
a = vcsn.context("lal_char(abc), b").ladybird(3)
a
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %% [markdown]
# Two cycles in $0$ with label "acac".

# %%
a.is_cycle_ambiguous()
# Out:
# True

# %%
# %%automaton -s a
# vcsn_context = "lal_char, b"
# $ -> 0
# 0 -> $
# 0 -> 1 a
# 0 -> 2 a
# 1 -> 0 b
# 1 -> 3 b
# 2 -> 1 c
# 2 -> 2 b
# 3 -> 1 c
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %% [markdown]
# Two cycles in $0$ with label "babc".

# %%
a.is_cycle_ambiguous()
# Out:
# True

# %%
# %%automaton -s a
# $ -> 0
# 0 -> $
# 1 -> 2 a
# 1 -> 3 a
# 2 -> 1 b
# 3 -> 1 b
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a.is_cycle_ambiguous()
# Out:
# True
