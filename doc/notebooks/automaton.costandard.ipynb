# %% [markdown]
# # _automaton_.costandard
#
# Turns an automaton into a costandard automaton.  This is equivalent to calling `_aut_.transpose().standard().transpose()`.
#
# Preconditions:
# - None
#
# Postconditions:
# - `result.is_costandard()`
#
# See also:
# - [_automaton_.costandard](automaton.costandard.ipynb)
# - [_automaton_.is_costandard](automaton.is_costandard.ipynb)

# %% [markdown]
# ## Examples

# %% [markdown]
# There is a single final state.

# %%
import vcsn
ctx = vcsn.context('lal_char(abc), z')
std = lambda e: ctx.expression(e).standard()
a = std('a').sum(std('b'), 'general')
a
# Out:
# mutable_automaton<context<letterset<char_letters>, z>>

# %%
a = a.costandard()
a
# Out:
# mutable_automaton<context<letterset<char_letters>, z>>

# %% [markdown]
# The final state has 1 as (final) weight.

# %%
a = a.costandard() * 2
a
# Out:
# mutable_automaton<context<letterset<char_letters>, z>>

# %%
a.costandard()
# Out:
# mutable_automaton<context<letterset<char_letters>, z>>

# %% [markdown]
# There is no outgoing transition from the final state.

# %%
# %%automaton -s a
# context = "lal_char(abc), z"
# $ -> 0 <2>
# 0 -> $ <2>
# 0 -> 1 a
# 1 -> 0 b
# Out:
# mutable_automaton<context<letterset<char_letters>, z>>

# %%
a.costandard()
# Out:
# mutable_automaton<context<letterset<char_letters>, z>>
