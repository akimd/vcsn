# %% [markdown]
# # _`automaton`_`.infiltration`
#
# Create the (accessible part of the) infiltration product of two automata.  In a way the infiltration product combines the conjunction (synchronized) and the shuffle product.
#
# Preconditions:
# - all the labelsets are letterized
#
# See also:
# - [conjunction](automaton.conjunction.ipynb)
# - [shuffle](automaton.shuffle.ipynb)

# %% [markdown]
# ## Examples

# %%
import vcsn
c = vcsn.context('lal_char, seriesset<lal_char, z>')
std = lambda exp: c.expression(exp).standard()
c
# Out:
# {...} -> RatE[{...} -> Z](distributive)

# %% [markdown]
# The following simple example aims at emphasizing that the transitions of the infiltration combine those of the shuffle and the conjunction products.

# %%
x = std("<x>a"); x
# Out:
# mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>

# %%
y = std("<y>a"); y
# Out:
# mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>

# %%
x & y
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %%
x.shuffle(y)
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %%
x.infiltration(y)
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %% [markdown]
# Don't be mistaken though: if in this example the sum of the shuffle and conjunction products indeed match the infiltration product, this no longer applies to larger automata.  In the following example (which nicely highlights the features of these three types of product) the transition from $(1, 0)$ to $(2, 1)$ would be missing.

# %%
xx = x * x
xx
# Out:
# mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>

# %%
yy = y * y
xx & yy
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %%
xx.shuffle(yy)
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %%
xx.infiltration(yy)
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %% [markdown]
# ### Associativity
# This operator is associative.

# %%
x = std('<x>a')
y = std('<y>a')
z = std('<z>a')

# %%
a = x.infiltration(y).infiltration(z); a
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %%
b = x.infiltration(y.infiltration(z)); b
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>>

# %%
a.strip().is_isomorphic(b.strip())
# Out:
# True

# %% [markdown]
# ### Variadicity

# %% [markdown]
# As a convenience, `infiltration` is variadic: it may accept more than two arguments.  However, it's (currently) only a wrapper around repeated calls to the binary operation (as can be seen by the parentheses in the state names below).

# %%
c = x.infiltration(y, z); c
# Out:
# tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, tuple_automaton<mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>, mutable_automaton<context<letterset<char_letters>, expressionset<context<letterset<char_letters>, z>>>>>

# %%
c.strip().is_isomorphic(a.strip())
# Out:
# True
