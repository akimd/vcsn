# %% [markdown]
# # `context`.`divkbaseb`(_`k`_, _`b`_)
#
# Generates an automaton that recognises the writing in base $b$ of the numbers divisible by the integer $k$.
#
# Preconditions:
# - $2 \le b$
# - the labelset has at least $b$ generators
#
# Postconditions:
# - the automaton has $k$ states

# %% [markdown]
# ## Examples

# %%
import vcsn
c = vcsn.context('lal_char(0-9), b')
c.divkbaseb(3, 2)
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
c.divkbaseb(2, 4)
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %% [markdown]
# If $k$ and $b$ are coprime, then the result is known to be minimal.

# %%
div4base4 = c.divkbaseb(4, 4)
div4base4
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
div4base4.minimize()
# Out:
# partition_automaton<mutable_automaton<context<letterset<char_letters>, b>>>
