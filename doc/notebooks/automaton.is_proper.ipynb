# %% [markdown]
# # _automaton_.is_proper
#
# Whether the automaton is proper, i.e. has no spontaneous transitions.
#
# See also:
# - [automaton.is_realtime](automaton.is_realtime.ipynb)
# - [automaton.proper](automaton.proper.ipynb)

# %% [markdown]
# ## Examples

# %%
import vcsn
exp = vcsn.context('[...] -> b').expression('ab')

# %%
a = exp.standard()
a
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a.is_proper()
# Out:
# True

# %%
a = exp.thompson()
a
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a.is_proper()
# Out:
# False
