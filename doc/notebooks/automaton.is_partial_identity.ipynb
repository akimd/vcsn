# %% [markdown]
# # _automaton_.is_partial_identity
#
# Whether the automaton is a partial identity, i.e. each (accepted) input is transduced to itself.
#
# Precondition:
# - The automaton is transducer.
# - The two tapes have the same labelset.
#
# See also:
# - [_automaton_.partial_identity](automaton.partial_identity.ipynb)

# %% [markdown]
# ## Examples

# %%
import vcsn

# %%
# %%automaton --strip a
# context = "lat<law(abc),law(abc)>, b"
# $ -> 0
# 0 -> 1 a|aa
# 1 -> 1 a|a
# 1 -> 2 aa|a
# 2 -> $
# Out:
# mutable_automaton<context<lat<wordset<char_letters>, wordset<char_letters>>, b>>

# %% [markdown]
# This transducer is a partial identity.

# %%
a.is_partial_identity()
# Out:
# True

# %% [markdown]
# However, the following transducer is not a partial identity, as it maps `aaa` to `aaaa`.

# %%
# %%automaton --strip a
# context = "lat<law(a),law(a)>, b"
# $ -> 0
# 0 -> 1 a|aa
# 0 -> 2 aa|a
# 1 -> 3 aa|aa
# 2 -> 3 aa|aa
# 3 -> $
# Out:
# mutable_automaton<context<lat<wordset<char_letters>, wordset<char_letters>>, b>>

# %%
a.is_partial_identity()
# Out:
# False
