# %% [markdown]
# # `automaton`.`pair`(`keep_initials` = `False`)
#
# The pair automaton, or $2$-subset automaton, is an intermediate representation used by the heuristics.
# It is defined by:
#
# $$
# \begin{align}
# Q' &= \{q_0\} \cup \{\{p, q\} \mid p, q \in Q, p \neq q\}
# \\
# \delta'(\{p, q\}, l) &=
#         \begin{cases}
#             q_0 & \text{if}~\delta(p, l) = \delta(q, l),\\
#             \{\delta(p, l), \delta(q, l)\} & \text{otherwise}.
#         \end{cases}
# \end{align}
# $$
#
# See also:
# - [automaton.synchronizing_word](automaton.synchronizing_word.ipynb)

# %% [markdown]
# ## Examples

# %%
import vcsn

# %%
# %%automaton a daut
# 0 -> 0 a
# 0 -> 1 b
# 1 -> 0 a
# 1 -> 1 b
# 2 -> 0 b
# 2 -> 1 a
# Out:
# name_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %%
a = a.strip()
a.pair()
# Out:
# pair_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %% [markdown]
# You also can keep the initial singleton states instead of merging them in a $q_0$ state:

# %%
a.pair(True)
# Out:
# pair_automaton<mutable_automaton<context<letterset<char_letters>, b>>>
