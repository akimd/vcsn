# %% [markdown]
# # _automaton_.is_ambigous
#
# Whether the automaton is ambiguous.
#
# Preconditions:
# - the automaton is free.
#
# Postconditions:
# - [_automaton_.ambiguous_word](automaton.ambiguous_word.ipynb) does not raise.
#
# See also:
# - [_automaton_.ambiguous_word](automaton.ambiguous_word.ipynb)

# %% [markdown]
# ## Examples

# %%
import vcsn
a = vcsn.context('lal_char(abcd), b').expression('abc').standard()
a
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a.is_ambiguous()
# Out:
# False

# %%
a + a
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
(a+a).is_ambiguous()
# Out:
# True
