# %% [markdown]
# # _expression_.thompson
#
# Generate the Thompson automaton from an expression.
#
# Preconditions:
# - the expression is basic.
#
# Caveats:
# - it is not guaranteed that `Result.is_valid()`
# - the context of the result might be different from the original context: spontaneous-transition support is required.
#
# Properties:
# - `Result.proper().is_isomorphic(r.standard())`
#
# See also:
# - [_expression_.automaton](expression.automaton.ipynb)

# %% [markdown]
# ## Examples

# %% [markdown]
# The Thompson procedure generates an automaton with spontaneous-transitions, which requires a labelset that features a "one" label.  The letterset and wordset labelsets (and their compositions) do support a "one" label.

# %%
import vcsn
vcsn.context('lal, b').expression('a[bc]d').thompson()
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
vcsn.context('law_char, b').expression("'aa'[bc]'dd'").thompson()
# Out:
# mutable_automaton<context<wordset<char_letters>, b>>

# %% [markdown]
# You may, however, use a labelset which does not feature a "one", in which case the context of the automaton will be different from the one of the expression.

# %%
vcsn.context('lal, b').expression("a").thompson().context()
# Out:
# {a...}? -> B

# %% [markdown]
# ### Weights

# %% [markdown]
# Weights are supported.

# %%
r = vcsn.context('lal(abc), q').expression('(<1/6>a*+<1/3>b*)*')
r
# Out:
# (<1/6>a*+<1/3>b*)*

# %%
t = r.thompson()
t
# Out:
# mutable_automaton<context<letterset<char_letters>, q>>

# %%
t.proper()
# Out:
# mutable_automaton<context<letterset<char_letters>, q>>

# %%
r.standard()
# Out:
# mutable_automaton<context<letterset<char_letters>, q>>

# %% [markdown]
# Note however that you may generate invalid automata (from invalid expressions):

# %%
t = vcsn.context('lal(abc), q').expression('\e*').thompson()
t
# Out:
# mutable_automaton<context<letterset<char_letters>, q>>

# %%
t.is_valid()
# Out:
# False
