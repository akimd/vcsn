# %% [markdown]
# # _automaton_.accessible
#
# Create a new automaton from the _accessible_ part of the input, i.e., the subautomaton whose states can be reached from an initial state.
#
# Preconditions:
# - None
#
# Postconditions:
# - Result.is_accessible()
#
# See also:
# - [_automaton_.is_accessible](automaton.is_accessible.ipynb)
# - [_automaton_.trim](automaton.trim.ipynb)

# %% [markdown]
# ## Examples

# %%
import vcsn

# %% [markdown]
# The following automaton has one unreachable state:

# %%
# %%automaton a
# context = "[abc]"
# $ -> 0
# 0 -> 1 a
# 1 -> $
# 2 -> 0 a
# 1 -> 3 a
# Out:
# name_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %%
a.is_accessible()
# Out:
# False

# %% [markdown]
# Calling `accessible` returns a copy of the automaton without non-accessible states:

# %%
a.accessible()
# Out:
# filter_automaton<name_automaton<mutable_automaton<context<letterset<char_letters>, b>>>>

# %%
a.accessible().is_accessible()
# Out:
# True
