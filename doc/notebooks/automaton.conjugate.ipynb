# %% [markdown]
# # automaton.conjugate
# Create the conjugate of an automaton.
# The conjugate of $\mathcal{A}$ is defined as the automaton recognizing the language $\{vu \mid u, v \in \Sigma^*\text{ and }uv\text{ recognized by }\mathcal{A}\}$.
#
# Preconditions:
# - labelset is nullable
#
# Postconditions:
# - None

# %% [markdown]
# # Examples

# %%
import vcsn

# %%
ctx = vcsn.context('[...] -> b')
a = ctx.expression('ab*').automaton()
a
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a.shortest(10)
# Out:
# a ⊕ ab ⊕ abb ⊕ abbb ⊕ abbbb ⊕ abbbbb ⊕ abbbbbb ⊕ abbbbbbb ⊕ abbbbbbbb ⊕ abbbbbbbbb

# %%
conj = a.conjugate()
conj
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
conj.shortest(10)
# Out:
# a ⊕ ab ⊕ ba ⊕ abb ⊕ bab ⊕ bba ⊕ abbb ⊕ babb ⊕ bbab ⊕ bbba
