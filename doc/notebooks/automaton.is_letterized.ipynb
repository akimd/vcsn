# %% [markdown]
# _automaton_.is_letterized
# ======

# %% [markdown]
# Whethere the automaton is _letterized_, i.e. each transition is labeled by a single letter. It's always true when labels are letters, for example.

# %% [markdown]
# Examples
# -----

# %%
import vcsn

# %%
a1 = vcsn.b.expression("ab+c*").standard()
a1
# Out:
# mutable_automaton<letterset<char_letters(abc)>, b>

# %%
a1.is_letterized()
# Out:
# True

# %% [markdown]
# Here, no computation is done, the result is implied by the labelset.

# %%
ctx = vcsn.context("law_char, b")
a2 = ctx.expression("a+bc*").standard()
a2
# Out:
# mutable_automaton<wordset<char_letters(abc)>, b>

# %%
a2.is_letterized()
# Out:
# True

# %% [markdown]
# Here, as labels can be words, each transition's label is checked to see that it is a letter (or the empty word).

# %%
a3 = ctx.expression("abc").standard()
a3
# Out:
# mutable_automaton<wordset<char_letters(abc)>, b>

# %%
a3.is_letterized()
# Out:
# False
