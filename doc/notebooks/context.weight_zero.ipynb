# %% [markdown]
# # _`context`_`.weight_zero()`
#
# The weight zero of a context.
#
# Preconditions:
# - `none`

# %%
import vcsn
def context(ctx):
    return vcsn.context(ctx)

# %%
context('lal, b').weight_zero()
# Out:
# 0

# %%
context('lal, z').weight_zero()
# Out:
# 0

# %%
context('lal, zmin').weight_zero()
# Out:
# oo
