# %% [markdown]
# # `expansion.conjunction(xpn)`
#
# Create an expansion which denotes the conjunction of both denoted series.
#
# Preconditions:
# - None
#
# See also:
# - [automaton.conjunction](automaton.conjunction.ipynb)
# - [expression.conjunction](expression.conjunction.ipynb)
# - [polynomial.conjunction](polynomial.conjunction.ipynb)
#
# References:
# - [demaille.2016.ictac](References.ipynb#demaille.2016.ictac) introduces expansions and their support for conjunction

# %% [markdown]
# ## Examples

# %%
import vcsn
def xpn(e):
    return vcsn.Q.expression(e).expansion()
a = xpn('<2>a*b')
a
# Out:
# a⊙[⟨2⟩a*b] ⊕ b⊙[⟨2⟩ε]

# %%
b = xpn('<3>ab*')
b
# Out:
# a⊙[⟨3⟩b*]

# %%
a & b
# Out:
# a⊙[⟨6⟩a*b&b*]

# %%
vcsn.Q.expression('<2>a*b & <3>ab*').derived_term()
# Out:
# expression_automaton<mutable_automaton<context<letterset<char_letters>, q>>>
