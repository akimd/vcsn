# %% [markdown]
# # _`automaton`_`.weight_series`
#
# Compute the sum of all the weights of the behavior. Find weighted distance between initial and final states.
#
# Implementations:
# - With a tropical weightset: Shortest path algorithm.
# - Otherwise: Proper applied to the spontaneous version of the automaton, i.e., as if all the labels were replaced by the empty word.

# %% [markdown]
# ## Examples

# %%
import vcsn

# %% [markdown]
# ### In a Tropical Semiring

# %%
# %%automaton a
# context = "lal_char, zmin"
# $ -> 0
# 0 -> 1 <6>a
# 0 -> 2 <1>a
# 2 -> 3 <1>b
# 3 -> 4 <1>c
# 4 -> 1 <1>d
# 0 -> 5 <2>a
# 5 -> 1 <3>b
# 1 -> $
# Out:
# name_automaton<mutable_automaton<context<letterset<char_letters>, zmin>>>

# %%
a.weight_series()
# Out:
# 4

# %% [markdown]
# ### In $\mathbb{Q}$

# %%
# %%automaton b
# context = "lal_char, q"
# $ -> 0
# 0 -> 1 <6>a
# 0 -> 2 <1>a
# 2 -> 3 <1>b
# 3 -> 4 <1>c
# 4 -> 1 <1>d
# 0 -> 5 <2>a
# 5 -> 1 <3>b
# 1 -> $
# Out:
# name_automaton<mutable_automaton<context<letterset<char_letters>, q>>>

# %%
b.weight_series()
# Out:
# 13
