# %% [markdown]
# # _automaton_.minimize(algo = "auto")

# %% [markdown]
# Minimizes a automaton
#
# The algorithm can be:
# - `"auto"`: same as `"signature"` for Boolean automaton on free labelsets, otherwise `"weighted"`
# - `"brzozowski"`: run determinization and codeterminization.
#   Requires a free labelset and Boolean weightset.
# - `"weighted"`: same as `"signature"` but accept non Boolean weightsets.
# - `"signature"`
# - `"moore"`
#   Requires a deterministic automaton.
#
# Preconditions:
# - its labelset is free
#
# Postconditions:
# - the result is equivalent to the input automaton
# - the result is deterministic
#
# See also:
# - [automaton.is_deterministic](automaton.is_deterministic.ipynb)
# - [automaton.cominimize](automaton.cominimize.ipynb)

# %% [markdown]
# ### Examples

# %%
import vcsn

# %%
# %%automaton a1
# context = "lal_char(abc), z"
# $ -> 0
# 0 -> 1 <2>a
# 0 -> 2 <3>a
# 1 -> 1 a
# 1 -> 3 <4>a
# 2 -> 2 a
# 2 -> 4 a
# 3 -> $
# 4 -> $
# Out:
# mutable_automaton<lal_char(abc), z>

# %% [markdown]
# ### Weighted

# %% [markdown]
# Using `minimize` or `minimize("weighted")`.

# %%
a1.minimize()
# Out:
# partition_automaton<mutable_automaton<lal_char(abc), z>>

# %% [markdown]
# ### Signature

# %%
# %%automaton a2
#   context = "lal_char(abcde), b"
#   $ -> 0
#   0 -> 1 a
#   0 -> 3 b
#   1 -> 1 a
#   1 -> 2 b
#   2 -> 2 a
#   2 -> 5 b
#   3 -> 3 a
#   3 -> 4 b
#   4 -> 4 a
#   4 -> 5 b
#   5 -> 5 a
#   5 -> 5 b
#   5 -> $
# Out:
# mutable_automaton<lal_char(abcde), b>

# %%
a2.minimize("signature")
# Out:
# partition_automaton<mutable_automaton<lal_char(abcde), b>>

# %% [markdown]
# ### Moore

# %%
a2.is_deterministic()
# Out:
# True

# %%
a2.minimize("moore")
# Out:
# partition_automaton<mutable_automaton<lal_char(abcde), b>>

# %% [markdown]
# ### Brzozowski

# %%
a2.minimize("brzozowski")
# Out:
# determinized_automaton<transpose_automaton<determinized_automaton<transpose_automaton<mutable_automaton<lal_char(abcde), b>>>>>
