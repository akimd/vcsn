# %% [markdown]
# # _automaton_.determinize

# %% [markdown]
# Computes the (accessible part of the) determinization of an automaton.

# %% [markdown]
# Preconditions:
# - its labelset is free
# - its weightset features a division operator (which is the case for $\mathbb{B}$).
#
# Postconditions:
# - the result is deterministic
# - the result is equivalent to the input automaton
# - the result is accessible
# - the result need not be complete
#
# Caveats:
# - might not terminate if the weightset is not $\mathbb{B}$
#
# See also:
# - [automaton.is_deterministic](automaton.is_deterministic.ipynb)

# %% [markdown]
# ## Examples

# %%
import vcsn

# %% [markdown]
# ### Ladybird

# %% [markdown]
# Ladybird is a well known example that shows the exponential growth on the number of resulting states.

# %%
lady4 = vcsn.context('lal_char(abc)_b').ladybird(4)
lady4
# Out:
# mutable_automaton<lal_char(abc)_b>

# %%
lady4d = lady4.determinize()
lady4d
# Out:
# determinized_automaton<mutable_automaton<lal_char(abc)_b>>

# %% [markdown]
# The resulting automaton has states labeled with subsets of the input automaton set of states.

# %% [markdown]
# ### Empty input

# %% [markdown]
# If the input automaton has an empty accessible part (i.e., it has no initial state), then the output is empty (which is genuinely displayed as nothing below).

# %%
# %%automaton a
# context = "lal_char(a)_b"
# 0 -> 1 a
# Out:
# mutable_automaton<lal_char(a)_b>

# %%
a.determinize()
# Out:
# determinized_automaton<mutable_automaton<lal_char(a)_b>>

# %% [markdown]
# ### Weighted automata

# %% [markdown]
# The algorithm we use requires a division operator.  The following example has weights in $\mathbb{Q}$.

# %%
a = vcsn.automaton('''digraph
{
  vcsn_context = "lal_char(abcd)_q"
  I0 -> 0 [label = "<2>"]
  0 -> 1 [label = "<2>a"]
  0 -> 2 [label = "<3>a"]
  1 -> 1 [label = "<3>b"]
  1 -> 3 [label = "<5>c"]
  2 -> 2 [label = "<3>b"]
  2 -> 3 [label = "<3>d"]
  3 -> F3
}''')
a
# Out:
# mutable_automaton<lal_char(abcd)_q>

# %%
d = a.determinize()
d
# Out:
# detweighted_automaton<mutable_automaton<lal_char(abcd)_q>>

# %% [markdown]
# Which is obviously deterministic.  Of course they are equivalent:

# %%
a.is_equivalent(d)
# Out:
# True

# %% [markdown]
# The next example works in $\mathbb{Z}_{\min}$, which features a division: the usual subtraction.

# %%
a = vcsn.automaton('''digraph
{
  vcsn_context = "lal_char(abcd)_zmin"
  I0 -> 0
  0 -> 1 [label = "<1>a"]
  0 -> 2 [label = "<2>a"]
  1 -> 1 [label = "<3>b"]
  1 -> 3 [label = "<5>c"]
  2 -> 2 [label = "<3>b"]
  2 -> 3 [label = "<6>d"]
  3 -> F3
}''')
a
# Out:
# mutable_automaton<lal_char(abcd)_zmin>

# %%
d = a.determinize()
d
# Out:
# detweighted_automaton<mutable_automaton<lal_char(abcd)_zmin>>

# %% [markdown]
# Of course, they are equivalent.  However we cannot use `is_equivalent` here.

# %%
a.shortest(10)
# Out:
# <6>ac + <8>ad + <9>abc + <11>abd + <12>abbc + <14>abbd + <15>abbbc + <17>abbbd + <18>abbbbc + <20>abbbbd

# %%
d.shortest(10)
# Out:
# <6>ac + <8>ad + <9>abc + <11>abd + <12>abbc + <14>abbd + <15>abbbc + <17>abbbd + <18>abbbbc + <20>abbbbd
